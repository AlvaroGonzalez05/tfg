# %% [markdown]
# This document is meant for exploratory data analysis, and additional uses helpful to the project

# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# Cargar dataset original
df = pd.read_csv("/Users/alvarogonzaleztabernero/Library/CloudStorage/OneDrive-UniversidadPontificiaComillas/ICAI/4/tfg_git/data/ev_charging_patterns.csv")  # Ajusta ruta si es necesario

# Seleccionar columnas representativas y mostrar primeras filas
df_subset = df[["Vehicle Model", "Battery Capacity (kWh)", "Charging Start Time", "Charging End Time", "State of Charge (Start %)", "State of Charge (End %)"]]
df_subset.head(5)
# Out:
#   Vehicle Model  Battery Capacity (kWh)  Charging Start Time  \
# 0        BMW i3              108.463007  2024-01-01 00:00:00
# 1  Hyundai Kona              100.000000  2024-01-01 01:00:00
# 2    Chevy Bolt               75.000000  2024-01-01 02:00:00
# 3  Hyundai Kona               50.000000  2024-01-01 03:00:00
# 4  Hyundai Kona               50.000000  2024-01-01 04:00:00
#
#      Charging End Time  State of Charge (Start %)  State of Charge (End %)
# 0  2024-01-01 00:39:00                  29.371576                86.119962
# 1  2024-01-01 03:01:00                  10.115778                84.664344
# 2  2024-01-01 04:48:00                   6.854604                69.917615
# 3  2024-01-01 06:42:00                  83.120003                99.624328
# 4  2024-01-01 05:46:00                  54.258950                63.743786

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,9))
df["Energy Consumed (kWh)"].hist(bins=30, edgecolor='black')
plt.title("Distribución de Energía Demandada")
plt.xlabel("Energía (kWh)")
plt.ylabel("Frecuencia")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
